# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.sample()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 216  CS-97217     B-     A-     A-         A      C     A-     A-     A-
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 216     C+  ...     B-     B-      C     C-     A-     A-     C-     B+
#
#     CS-412   CGPA
# 216     A-  2.931
#
# [1 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['CGPA'].unique()
# Out:
# array([2.205, 2.008, 3.608, 1.906, 3.448, 3.026, 2.957, 3.043, 3.358,
#        3.247, 2.681, 3.281, 2.792, 3.523, 3.443, 2.777, 3.248, 1.787,
#        3.572, 3.483, 2.246, 2.956, 2.953, 3.586, 3.475, 2.228, 3.44 ,
#        2.188, 3.195, 2.294, 3.133, 3.22 , 3.112, 3.16 , 3.019, 3.164,
#        3.332, 2.165, 3.7  , 3.033, 2.696, 2.851, 3.058, 1.493, 2.069,
#        1.996, 3.897, 3.848, 3.404, 2.254, 2.655, 3.106, 2.793, 3.023,
#        3.01 , 3.4  , 1.899, 3.168, 2.57 , 2.418, 2.564, 2.468, 3.769,
#        2.999, 2.768, 2.822, 3.189, 2.715, 3.578, 3.49 , 2.805, 3.458,
#        2.34 , 3.252, 2.683, 3.378, 3.295, 3.193, 3.647, 2.815, 2.171,
#        3.761, 2.763, 2.938, 2.06 , 1.261, 2.378, 2.861, 2.363, 2.084,
#        1.38 , 1.89 , 3.861, 1.805, 3.925, 3.919, 3.258, 3.963, 2.396,
#        3.772, 1.768, 3.176, 3.335, 3.758, 3.208, 1.845, 3.946, 2.3  ,
#        3.759, 3.516, 2.087, 3.137, 2.011, 2.566, 1.993, 3.334, 2.056,
# ...

# %%
df['CGPA'].nunique()
# Out:
# 491

# %%
#making dataframe for the Nominal data
df_visualization_nominal=df[['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111','CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214','EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301','CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312','CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423','CS-412']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412'],
#       dtype='object')

# %%
#visualization of data
ax=sns.countplot(x='Seat No.', data=df_visualization_nominal)
print(df_visualization_nominal["Seat No."].value_counts())
# Out:
# CS-97001    1
# CS-97384    1
# CS-97378    1
# CS-97379    1
# CS-97380    1
#            ..
# CS-97185    1
# CS-97184    1
# CS-97183    1
# CS-97182    1
# CS-97571    1
# Name: Seat No., Length: 571, dtype: int64

# %%
ax=sns.countplot(x='PH-121', data=df_visualization_nominal)
print(df_visualization_nominal["PH-121"].value_counts())
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %%
ax=sns.countplot(x='HS-101', data=df_visualization_nominal)
print(df_visualization_nominal["HS-101"].value_counts())
# Out:
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64

# %%
ax=sns.countplot(x='CY-105', data=df_visualization_nominal)
print(df_visualization_nominal["CY-105"].value_counts())
# Out:
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64

# %%
ax=sns.countplot(x='HS-105/12', data=df_visualization_nominal)
print(df_visualization_nominal["HS-105/12"].value_counts())
# Out:
# A     96
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64

# %%
ax=sns.countplot(x='MT-111', data=df_visualization_nominal)
print(df_visualization_nominal["MT-111"].value_counts())
# Out:
# A-    105
# A     100
# B-     70
# B+     62
# B      55
# C-     39
# C+     33
# C      30
# D      26
# A+     23
# D+     21
# WU      3
# F       2
# Name: MT-111, dtype: int64

# %%
ax=sns.countplot(x='CS-105', data=df_visualization_nominal)
print(df_visualization_nominal["CS-105"].value_counts())
# Out:
# A     151
# A-    134
# B+     60
# B      51
# A+     43
# B-     38
# C+     23
# C      22
# C-     22
# D+     15
# D      12
# Name: CS-105, dtype: int64

# %%
ax=sns.countplot(x='CS-106', data=df_visualization_nominal)
print(df_visualization_nominal["CS-106"].value_counts())
# Out:
# A-    116
# B+    101
# B      96
# A      56
# B-     54
# C+     41
# D+     29
# C-     27
# D      24
# C      18
# A+      4
# WU      2
# F       1
# Name: CS-106, dtype: int64

# %%
ax=sns.countplot(x='EL-102', data=df_visualization_nominal)
print(df_visualization_nominal["EL-102"].value_counts())
# Out:
# A-    105
# A      92
# B+     69
# B      59
# B-     53
# D      38
# C+     35
# C-     32
# C      30
# A+     29
# D+     23
# WU      3
# F       1
# Name: EL-102, dtype: int64

# %%
ax=sns.countplot(x='EE-119', data=df_visualization_nominal)
print(df_visualization_nominal["EE-119"].value_counts())
# Out:
# A-    137
# B+     83
# B      77
# A      68
# B-     48
# C      48
# C+     38
# D+     26
# C-     26
# D      11
# A+      6
# WU      1
# Name: EE-119, dtype: int64

# %%
ax=sns.countplot(x='ME-107', data=df_visualization_nominal)
print(df_visualization_nominal["ME-107"].value_counts())
# Out:
# A-    79
# A     77
# B+    68
# D     56
# B-    56
# B     50
# C     49
# C-    48
# C+    37
# D+    37
# A+     8
# WU     2
# F      2
# Name: ME-107, dtype: int64

# %%
ax=sns.countplot(x='CS-107', data=df_visualization_nominal)
print(df_visualization_nominal["CS-107"].value_counts())
# Out:
# A     105
# A-     81
# B+     57
# B      55
# C-     49
# B-     43
# A+     42
# D      38
# C+     34
# D+     31
# C      30
# WU      2
# I       1
# F       1
# Name: CS-107, dtype: int64

# %%
ax=sns.countplot(x='HS-205/20', data=df_visualization_nominal)
print(df_visualization_nominal["HS-205/20"].value_counts())
# Out:
# A-    150
# A     118
# B      97
# B+     89
# B-     36
# C+     33
# C      15
# C-     11
# D+      9
# D       3
# A+      2
# F       2
# WU      1
# Name: HS-205/20, dtype: int64

# %%
ax=sns.countplot(x='MT-222', data=df_visualization_nominal)
print(df_visualization_nominal["MT-222"].value_counts())
# Out:
# A-    86
# A     80
# D     66
# B     61
# B-    52
# D+    46
# C     43
# B+    42
# C+    39
# C-    30
# A+    16
# F      3
# WU     1
# W      1
# Name: MT-222, dtype: int64

# %%
ax=sns.countplot(x='EE-222', data=df_visualization_nominal)
print(df_visualization_nominal["EE-222"].value_counts())
# Out:
# A     122
# A-    121
# B+     65
# B      53
# C      39
# B-     35
# A+     32
# C+     29
# D      25
# D+     21
# C-     16
# F       4
# W       2
# Name: EE-222, dtype: int64

# %%
ax=sns.countplot(x='MT-224', data=df_visualization_nominal)
print(df_visualization_nominal["MT-224"].value_counts())
# Out:
# A-    120
# A      80
# B+     65
# B      57
# B-     49
# C-     43
# C+     39
# D+     37
# D      31
# C      30
# A+     10
# WU      1
# W       1
# F       1
# Name: MT-224, dtype: int64

# %%
ax=sns.countplot(x='CS-210', data=df_visualization_nominal)
print(df_visualization_nominal["CS-210"].value_counts())
# Out:
# A-    133
# A     101
# B+     84
# B      59
# B-     58
# C      30
# C+     27
# C-     24
# D+     21
# D      12
# A+     12
# WU      1
# W       1
# F       1
# Name: CS-210, dtype: int64

# %%
ax=sns.countplot(x='CS-211', data=df_visualization_nominal)
print(df_visualization_nominal["CS-211"].value_counts())
# Out:
# A-    68
# A     67
# B-    60
# D+    56
# B+    56
# B     56
# C+    55
# C-    50
# C     39
# D     33
# A+    21
# F      3
# WU     1
# W      1
# Name: CS-211, dtype: int64

# %%
ax=sns.countplot(x='CS-203', data=df_visualization_nominal)
print(df_visualization_nominal["CS-203"].value_counts())
# Out:
# A-    88
# A     81
# B     66
# C+    62
# B+    59
# B-    53
# D+    39
# C     35
# C-    35
# D     30
# A+    15
# F      2
# I      1
# Name: CS-203, dtype: int64

# %%
ax=sns.countplot(x='CS-214', data=df_visualization_nominal)
print(df_visualization_nominal["CS-214"].value_counts())
# Out:
# C     76
# A-    73
# B     63
# C-    57
# B-    56
# A     56
# D+    47
# C+    46
# B+    45
# D     31
# A+    12
# F      2
# I      1
# Name: CS-214, dtype: int64

# %%
ax=sns.countplot(x='EE-217', data=df_visualization_nominal)
print(df_visualization_nominal["EE-217"].value_counts())
# Out:
# A-    137
# A      97
# B+     70
# B      63
# B-     57
# C      36
# C+     29
# A+     22
# C-     20
# D+     19
# D      12
# F       2
# WU      1
# Name: EE-217, dtype: int64

# %%
ax=sns.countplot(x='CS-212', data=df_visualization_nominal)
print(df_visualization_nominal["CS-212"].value_counts())
# Out:
# A-    101
# B+     86
# B      81
# B-     65
# C      44
# A      43
# D+     36
# C+     35
# C-     35
# D      33
# A+      4
# WU      2
# Name: CS-212, dtype: int64

# %%
ax=sns.countplot(x='CS-215', data=df_visualization_nominal)
print(df_visualization_nominal["CS-215"].value_counts())
# Out:
# A-    79
# A     68
# B     64
# B-    59
# C+    50
# B+    50
# C     48
# C-    47
# D     42
# D+    38
# A+    17
# WU     1
# W      1
# F      1
# Name: CS-215, dtype: int64

# %%
ax=sns.countplot(x='MT-331', data=df_visualization_nominal)
print(df_visualization_nominal["MT-331"].value_counts())
# Out:
# A     118
# A-    103
# B+     64
# B      57
# B-     46
# C-     32
# D+     31
# A+     30
# C      28
# C+     27
# D      22
# F       4
# Name: MT-331, dtype: int64

# %%
ax=sns.countplot(x='EF-303', data=df_visualization_nominal)
print(df_visualization_nominal["EF-303"].value_counts())
# Out:
# B     112
# B-     92
# C      61
# B+     59
# C+     58
# C-     56
# D+     49
# A-     38
# D      19
# A      14
# F       2
# WU      1
# Name: EF-303, dtype: int64

# %%
ax=sns.countplot(x='HS-304', data=df_visualization_nominal)
print(df_visualization_nominal["HS-304"].value_counts())
# Out:
# A-    128
# B      72
# B-     70
# B+     66
# C      58
# C+     53
# C-     33
# A      28
# D      20
# D+     19
# F       6
# A+      4
# WU      2
# W       2
# Name: HS-304, dtype: int64

# %%
ax=sns.countplot(x='CS-301', data=df_visualization_nominal)
print(df_visualization_nominal["CS-301"].value_counts())
# Out:
# A-    108
# B+     74
# B      71
# A      66
# B-     60
# C      41
# C+     37
# C-     36
# D      29
# D+     29
# A+      9
# F       1
# Name: CS-301, dtype: int64

# %%
ax=sns.countplot(x='CS-302', data=df_visualization_nominal)
print(df_visualization_nominal["CS-302"].value_counts())
# Out:
# A-    113
# B     102
# A      86
# B+     81
# B-     60
# C+     32
# C      28
# D      21
# C-     19
# D+     10
# A+      9
# Name: CS-302, dtype: int64

# %%
ax=sns.countplot(x='TC-383', data=df_visualization_nominal)
print(df_visualization_nominal["TC-383"].value_counts())
# Out:
# A     105
# A-     73
# B+     68
# B      59
# C+     44
# D+     44
# C-     42
# C      42
# B-     40
# A+     23
# D      20
# F       1
# Name: TC-383, dtype: int64

# %%
ax=sns.countplot(x='MT-442', data=df_visualization_nominal)
print(df_visualization_nominal["MT-442"].value_counts())
# Out:
# A-    140
# A     130
# B+     65
# B      47
# A+     39
# B-     30
# C-     28
# C+     24
# C      24
# D      20
# D+     13
# F       1
# Name: MT-442, dtype: int64

# %%
ax=sns.countplot(x='EL-332', data=df_visualization_nominal)
print(df_visualization_nominal["EL-332"].value_counts())
# Out:
# A-    96
# A     76
# B+    68
# B     67
# B-    62
# C     49
# C+    38
# C-    32
# D+    22
# D     22
# A+    20
# F      9
# WU     1
# Name: EL-332, dtype: int64

# %%
ax=sns.countplot(x='CS-318', data=df_visualization_nominal)
print(df_visualization_nominal["CS-318"].value_counts())
# Out:
# A-    89
# B-    69
# B     68
# B+    65
# C     53
# C+    49
# A     42
# C-    40
# D     36
# D+    29
# F     10
# A+     6
# WU     5
# W      1
# Name: CS-318, dtype: int64

# %%
ax=sns.countplot(x='CS-306', data=df_visualization_nominal)
print(df_visualization_nominal["CS-306"].value_counts())
# Out:
# A-    120
# B+     75
# A      74
# B-     64
# B      53
# C-     40
# C      37
# C+     36
# D      31
# D+     18
# A+     10
# F       3
# WU      1
# Name: CS-306, dtype: int64

# %%
ax=sns.countplot(x='CS-312', data=df_visualization_nominal)
print(df_visualization_nominal["CS-312"].value_counts())
# Out:
# A+    93
# A     86
# A-    63
# D+    52
# C     48
# C-    44
# B+    42
# B     37
# C+    37
# B-    36
# D     19
# F      2
# W      1
# WU     1
# Name: CS-312, dtype: int64

# %%
ax=sns.countplot(x='CS-412', data=df_visualization_nominal)
print(df_visualization_nominal["CS-412"].value_counts())
# Out:
# A-    157
# B+     80
# A      77
# B      65
# B-     37
# C+     24
# C      19
# D+      8
# C-      7
# F       6
# D       5
# A+      4
# W       3
# Name: CS-412, dtype: int64

# %%
ax=sns.countplot(x='CS-317', data=df_visualization_nominal)
print(df_visualization_nominal["CS-317"].value_counts())
# Out:
# B-    79
# B     75
# C     70
# A-    66
# B+    58
# C+    57
# A     47
# C-    41
# D+    34
# D     16
# A+     9
# F      7
# Name: CS-317, dtype: int64

# %%
ax=sns.countplot(x='CS-403', data=df_visualization_nominal)
print(df_visualization_nominal["CS-403"].value_counts())
# Out:
# A     133
# A-    106
# B+     62
# B-     55
# B      54
# D+     35
# C      33
# C+     32
# C-     30
# A+     15
# D       4
# Name: CS-403, dtype: int64

# %%
ax=sns.countplot(x='CS-421', data=df_visualization_nominal)
print(df_visualization_nominal["CS-421"].value_counts())
# Out:
# B     86
# B-    74
# C     68
# C+    61
# C-    60
# B+    60
# A-    47
# D+    36
# A     25
# D     21
# F     17
# A+     2
# W      2
# Name: CS-421, dtype: int64

# %%
ax=sns.countplot(x='CS-406', data=df_visualization_nominal)
print(df_visualization_nominal["CS-406"].value_counts())
# Out:
# A-    177
# A      79
# B+     64
# B      58
# B-     22
# C+     22
# C      19
# D+     14
# C-      8
# A+      8
# F       6
# D       5
# W       3
# WU      1
# Name: CS-406, dtype: int64

# %%
ax=sns.countplot(x='CS-414', data=df_visualization_nominal)
print(df_visualization_nominal["CS-414"].value_counts())
# Out:
# A     176
# A-    156
# B+     62
# B      54
# B-     21
# A+     21
# C+     21
# C      20
# C-     12
# F       7
# D+      3
# D       3
# W       2
# Name: CS-414, dtype: int64

# %%
ax=sns.countplot(x='CS-419', data=df_visualization_nominal)
print(df_visualization_nominal["CS-419"].value_counts())
# Out:
# A-    120
# B      89
# B+     85
# B-     78
# A      56
# C+     46
# C      40
# C-     20
# D+     13
# D       7
# A+      2
# F       2
# Name: CS-419, dtype: int64

# %%
ax=sns.countplot(x='CS-423', data=df_visualization_nominal)
print(df_visualization_nominal["CS-423"].value_counts())
# Out:
# A-    122
# A      78
# B+     75
# B      65
# B-     56
# C      45
# C+     39
# C-     29
# D+     25
# D      15
# F       5
# A+      3
# Name: CS-423, dtype: int64

# %%
sns.distplot(df['CGPA'],kde=True)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Density'>

# %%
# 42 categorical data is present, so we have convert categorical data into numerical data with the help of label encoder
from sklearn.preprocessing import LabelEncoder
cols=['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412']

# %%
df[cols] = df[cols].apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
#describe the dataset
df.describe()
# Out:
#          Seat No.      PH-121      HS-101      CY-105   HS-105/12      MT-111  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean   285.000000    3.781086    5.071804    2.921191    4.264448    3.935201
# std    164.977776    3.046895    2.785317    2.992228    3.216478    3.034481
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    142.500000    2.000000    3.000000    0.000000    2.000000    2.000000
# 50%    285.000000    3.000000    5.000000    2.000000    4.000000    4.000000
# 75%    427.500000    6.000000    7.000000    5.000000    7.000000    6.000000
# max    570.000000   12.000000   11.000000   13.000000   13.000000   13.000000
#
#            CS-105      CS-106      EL-102      EE-119  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.838879    4.161121    3.998249    3.921191  ...    4.299475
# ...

# %%
# visualize df.describe
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
#corelation of the column with target variable
df.corr()['CGPA'].sort_values()
# Out:
# EL-332      -0.803475
# CS-317      -0.800771
# CS-210      -0.798841
# CS-306      -0.783624
# CS-302      -0.770868
# CS-215      -0.768707
# CS-214      -0.758407
# MT-111      -0.756109
# CS-301      -0.747775
# MT-224      -0.743577
# CS-421      -0.742041
# CS-419      -0.732899
# EE-217      -0.703131
# MT-222      -0.695418
# CS-212      -0.686163
# CS-203      -0.682817
# TC-383      -0.682447
# ME-107      -0.677342
# CY-105      -0.670190
# CS-211      -0.669814
# EL-102      -0.669536
# EE-119      -0.668787
# PH-121      -0.663135
# CS-318      -0.660106
# CS-403      -0.657128
# HS-304      -0.656729
# MT-442      -0.656557
# CS-107      -0.650531
# EE-222      -0.644384
# HS-105/12   -0.627644
# CS-423      -0.624558
# CS-105      -0.613169
# MT-331      -0.610787
# EF-303      -0.589066
# CS-106      -0.563178
# CS-312      -0.562341
# HS-101      -0.537170
# CS-414      -0.512836
# HS-205/20   -0.500668
# CS-412      -0.470128
# CS-406      -0.280626
# ...

# %%
#visualised the corelation
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['CGPA'].sort_values(ascending=False).drop(['CGPA']).plot(kind='bar')
plt.xlabel('subject',fontsize=14)
plt.ylabel('CGPA',fontsize=14)
plt.title('corelation',fontsize=16)
plt.show()

# %%
df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105       1.001752
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20    1.155648
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# ...

# %% [markdown]
# Observation shows skewness is present
# but skewnwss is not apply on categorical data and target variable so we conclude here that no skewness is present because our dataframe contain categorical data

# %%
data_loss=(df.shape[0]-df.shape[0])/df.shape[0]
data_loss
# Out:
# 0.0

# %% [markdown]
# we dont have data loss here

# %% [markdown]
# # splitting dataset into x and y

# %%
x= df.drop("CGPA",axis=1)
x
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
x.shape
# Out:
# (571, 42)

# %%
y=df["CGPA"]
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
y.shape
# Out:
# (571,)

# %% [markdown]
# # scaling data into MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
st=MinMaxScaler()

# %%
x=st.fit_transform(x)
x
# Out:
# array([[0.        , 0.41666667, 0.90909091, ..., 0.66666667, 0.25      ,
#         0.15384615],
#        [0.00175439, 0.        , 0.81818182, ..., 0.5       , 0.5       ,
#         0.23076923],
#        [0.00350877, 0.        , 0.27272727, ..., 0.        , 0.16666667,
#         0.        ],
#        ...,
#        [0.99649123, 0.25      , 0.        , ..., 0.33333333, 0.16666667,
#         0.15384615],
#        [0.99824561, 0.        , 0.36363636, ..., 0.25      , 0.41666667,
#         0.46153846],
#        [1.        , 0.5       , 0.81818182, ..., 0.33333333, 0.75      ,
#         0.61538462]])

# %%
xf=pd.DataFrame(data=x)
xf
# Out:
#            0         1         2         3         4         5    6   \
# 0    0.000000  0.416667  0.909091  0.615385  0.461538  0.615385  1.0
# 1    0.001754  0.000000  0.818182  0.769231  0.692308  0.384615  0.6
# 2    0.003509  0.000000  0.272727  0.000000  0.384615  0.307692  0.0
# 3    0.005263  0.750000  0.636364  0.769231  0.692308  0.692308  0.2
# 4    0.007018  0.166667  0.181818  0.153846  0.307692  0.000000  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 566  0.992982  0.250000  0.000000  0.000000  0.153846  0.076923  0.0
# 567  0.994737  0.083333  0.000000  0.000000  0.000000  0.000000  0.0
# 568  0.996491  0.250000  0.000000  0.153846  0.307692  0.000000  0.0
# 569  0.998246  0.000000  0.363636  0.692308  0.000000  0.692308  1.0
# 570  1.000000  0.500000  0.818182  0.692308  0.461538  0.461538  1.0
#
#            7         8         9   ...        32        33        34  \
# ...

# %%
x=xf
x
# Out:
#            0         1         2         3         4         5    6   \
# 0    0.000000  0.416667  0.909091  0.615385  0.461538  0.615385  1.0
# 1    0.001754  0.000000  0.818182  0.769231  0.692308  0.384615  0.6
# 2    0.003509  0.000000  0.272727  0.000000  0.384615  0.307692  0.0
# 3    0.005263  0.750000  0.636364  0.769231  0.692308  0.692308  0.2
# 4    0.007018  0.166667  0.181818  0.153846  0.307692  0.000000  0.0
# ..        ...       ...       ...       ...       ...       ...  ...
# 566  0.992982  0.250000  0.000000  0.000000  0.153846  0.076923  0.0
# 567  0.994737  0.083333  0.000000  0.000000  0.000000  0.000000  0.0
# 568  0.996491  0.250000  0.000000  0.153846  0.307692  0.000000  0.0
# 569  0.998246  0.000000  0.363636  0.692308  0.000000  0.692308  1.0
# 570  1.000000  0.500000  0.818182  0.692308  0.461538  0.461538  1.0
#
#            7         8         9   ...        32        33        34  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i}, training accuracy is :- {r2_score(y_train,pred_train)}")
    print(f"At random state {i}, testing accuracy is :- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, training accuracy is :- 0.9544988995613733
# At random state 0, testing accuracy is :- 0.9536742854391194
#
#
# At random state 1, training accuracy is :- 0.9526415149226131
# At random state 1, testing accuracy is :- 0.9638233007233492
#
#
# At random state 2, training accuracy is :- 0.9669317596645328
# At random state 2, testing accuracy is :- 0.8845383409985241
#
#
# At random state 3, training accuracy is :- 0.9633494447758092
# At random state 3, testing accuracy is :- 0.9194971837751184
#
#
# At random state 4, training accuracy is :- 0.9528656370883457
# At random state 4, testing accuracy is :- 0.9629371337252507
#
#
# At random state 5, training accuracy is :- 0.9534107920701032
# At random state 5, testing accuracy is :- 0.9589759519279504
#
#
# At random state 6, training accuracy is :- 0.9544643896791697
# At random state 6, testing accuracy is :- 0.9567617109930062
#
#
# At random state 7, training accuracy is :- 0.9581653974815316
# ...

# %% [markdown]
# we take random state = 75 because it gives high testing accuracy

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=75)

# %%
#train the model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9736627069700976

# %% [markdown]
# # cross validation for the model

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

# %%
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.863662050623279 and accuracy score for training is -0.9146728072960275 and accuracy for testing is 0.9736627069700976
#
#
# At cross fold 3 the cv score is 0.9015718337379871 and accuracy score for training is -0.9146728072960275 and accuracy for testing is 0.9736627069700976
#
#
# At cross fold 4 the cv score is 0.9055220677346689 and accuracy score for training is -0.9146728072960275 and accuracy for testing is 0.9736627069700976
#
#
# At cross fold 5 the cv score is 0.9311874898838226 and accuracy score for training is -0.9146728072960275 and accuracy for testing is 0.9736627069700976
#
#
# At cross fold 6 the cv score is 0.9349660439760935 and accuracy score for training is -0.9146728072960275 and accuracy for testing is 0.9736627069700976
#
#
# At cross fold 7 the cv score is 0.9362744002539306 and accuracy score for training is -0.9146728072960275 and accuracy for testing is 0.9736627069700976
#
#
# ...

# %% [markdown]
# we select cross fold 8

# %%
#visualization
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('actual CGPA',fontsize=12)
plt.ylabel('predicted CGPA',fontsize=12)
plt.title('linear regression')
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# # regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn .linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}

# %%
ls=Lasso()

# %%
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %% [markdown]
# # final model training

# %%
ls=Lasso(alpha= 0.0001, random_state= 0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 95.04219626606397

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 97.47876891785619

# %%
cv_score=cross_val_score(ls,x,y,cv=8)
cv_mean=cv_score.mean()

# %%
cv_mean*100
# Out:
# 93.86851630288089

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion= 'mse', max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('r2_score = ',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=8)
rfc=rfscore.mean()
print('cross val score: ',rfc*100)
# Out:
# r2_score =  97.43861554996312
# cross val score:  95.20170074565264

# %% [markdown]
# we are getting model accuracy as 97.4386 and cross val score as 95.20 which shows that model working well

# %%
import pickle
filename='grades.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
#conclusion
loaded_model=pickle.load(open('grades.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 97.43861554996312

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","original"])
conclusion
# Out:
#                0        1        2        3        4        5       6    \
# predicted  3.52809  2.77566  2.21391  3.37535  3.14123  2.74404  2.8066
# original   3.52809  2.77566  2.21391  3.37535  3.14123  2.74404  2.8066
#
#                7        8        9    ...      105      106     107     108  \
# predicted  2.09204  2.49492  3.86992  ...  3.55036  3.42778  3.2038  3.4224
# original   2.09204  2.49492  3.86992  ...  3.55036  3.42778  3.2038  3.4224
#
#                109      110      111      112      113      114
# predicted  3.88946  2.39826  2.09266  1.95154  3.19582  3.30434
# original   3.88946  2.39826  2.09266  1.95154  3.19582  3.30434
#
# [2 rows x 115 columns]
